# %%
# Cellule 1 — toujours en premier
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.losses import DiceLoss, DiceCELoss

import torch
import nbimporter
from PreProcess_train import prepare
from Utilities import train

import matplotlib.pyplot as plt
data_dir = 'C:/Users/rowan/Desktop/Projets/Liver Segmentation/datasets/nifti_files'
model_dir = 'C:/Users/rowan/Desktop/Projets/Liver Segmentation/Results'

device=torch.device("cpu")
data_in=prepare(data_dir)
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256), 
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(model.parameters(),1e-4, weight_decay=1e-4, amsgrad=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 11
#       9 import nbimporter
#      10 from PreProcess_train import prepare
# ---> 11 from Utilities import train
#      13 import matplotlib.pyplot as plt
#      14 data_dir = 'C:/Users/rowan/Desktop/Projets/Liver Segmentation/datasets/nifti_files'
#
# ModuleNotFoundError: No module named 'Utilities'

# %%
train(model, data_in, loss_function, optimizer, 5, model_dir)

# %%
import os
print(os.listdir("../notebooks/"))
# Out:
# ['.ipynb_checkpoints', '01-Preparation.nii.ipynb', '02-PreProcess_train.ipynb', '03-Train.ipynb', '04-Testing.ipynb', '05-Utilities.ipynb', '06-PostProcessing.ipynb']
